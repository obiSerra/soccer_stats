# %%
import pandas as pd
import json
import matplotlib.pyplot as plt 
import numpy as np
from IPython.display import HTML, Markdown, display

# %%
df = pd.read_csv('data/full_data.csv')

# %% [markdown]
# *Search for the id of the 2 teams*

# %%
league = "Bundesliga"

df[df['league'] == league][['team_title', 'team_id']].drop_duplicates()
# Out:
#                  team_title  team_id
# 280           Bayern Munich      117
# 285        Bayer Leverkusen      119
# 290              Hoffenheim      120
# 295                Augsburg      121
# 300           Werder Bremen      123
# 305                Mainz 05      125
# 310       Borussia Dortmund      129
# 315     Borussia M.Gladbach      130
# 320               Wolfsburg      131
# 325     Eintracht Frankfurt      132
# 330           VfB Stuttgart      133
# 335                Freiburg      135
# 340  RasenBallsport Leipzig      136
# 345            Union Berlin      240
# 350                  Bochum      268
# 355           FC Heidenheim      280
# 360           Holstein Kiel      287
# 365               St. Pauli      288

# %%
league = "Serie_A"

df[df['league'] == league][['team_title', 'team_id']].drop_duplicates()
# Out:
#             team_title  team_id
# 370             Verona       94
# 376               Roma       95
# 382              Lazio       96
# 388            Bologna       97
# 394           Juventus       98
# 400            Udinese       99
# 406              Genoa      101
# 412             Napoli      105
# 418              Inter      106
# 424           Atalanta      107
# 430             Empoli      108
# 436         Fiorentina      110
# 442           AC Milan      111
# 448             Torino      113
# 454           Cagliari      116
# 460  Parma Calcio 1913      230
# 466              Lecce      243
# 472            Venezia      265
# 478              Monza      271
# 484               Como      286

# %%
team_1 = "Juventus"
team_2 = "RasenBallsport Leipzig"

# %%
team_1_df = df[(df['team_title'] == team_1)]
team_1_df.head()
# Out:
#       league  team_id team_title  gameweek h_a        xG       xGA      npxG  \
# 394  Serie_A       98   Juventus         1   h  1.305820  0.171238  1.305820
# 395  Serie_A       98   Juventus         2   a  1.361510  0.878611  0.600212
# 396  Serie_A       98   Juventus         3   h  0.415282  0.382591  0.415282
# 397  Serie_A       98   Juventus         4   a  0.726024  0.601249  0.726024
# 398  Serie_A       98   Juventus         5   h  0.419301  0.233773  0.419301
#
#         npxGA   ppda  ...  loses  pts     npxGD  adv_id  adv_title  \
# 394  0.171238  15.25  ...      0    3  1.134582     286       Como
# 395  0.878611  12.24  ...      0    3 -0.278399      94     Verona
# 396  0.382591  16.59  ...      0    1  0.032691      95       Roma
# 397  0.601249  13.79  ...      0    1  0.124775     108     Empoli
# 398  0.233773   8.91  ...      0    1  0.185528     105     Napoli
#
#      forecast_w forecast_d forecast_l   xG_diff  xGA_diff
# 394      0.0388     0.2456     0.7156 -1.694180  0.171238
# 395      0.1874     0.3109     0.5017 -1.638490  0.878611
# 396      0.2269     0.5223     0.2508  0.415282  0.382591
# 397      0.2754     0.3959     0.3287  0.726024  0.601249
# 398      0.1433     0.5664     0.2903  0.419301  0.233773
#
# [5 rows x 30 columns]

# %%
team_2_df = df[(df['team_title'] == team_2)]
team_2_df.head()
# Out:
#          league  team_id              team_title  gameweek h_a        xG  \
# 340  Bundesliga      136  RasenBallsport Leipzig         1   h  0.937134
# 341  Bundesliga      136  RasenBallsport Leipzig         2   a  1.505320
# 342  Bundesliga      136  RasenBallsport Leipzig         3   h  1.294620
# 343  Bundesliga      136  RasenBallsport Leipzig         4   a  0.841324
# 344  Bundesliga      136  RasenBallsport Leipzig         5   h  2.815930
#
#           xGA      npxG     npxGA   ppda  ...  loses  pts     npxGD  adv_id  \
# 340  1.315410  0.937134  1.315410  12.92  ...      0    3 -0.378276     268
# 341  3.422660  1.505320  3.422660  12.39  ...      0    3 -1.917340     119
# 342  0.859112  0.536839  0.859112   8.73  ...      0    1 -0.322273     240
# 343  1.672850  0.841324  1.672850   6.17  ...      0    1 -0.831526     288
# 344  1.074150  2.815930  0.316378  14.50  ...      0    3  2.499552     121
#
#             adv_title  forecast_w forecast_d forecast_l   xG_diff  xGA_diff
# 340            Bochum      0.4767     0.2932     0.2301 -0.062866  1.315410
# 341  Bayer Leverkusen      0.7866     0.1337     0.0797 -1.494680  1.422660
# 342      Union Berlin      0.2016     0.3072     0.4912  1.294620  0.859112
# 343         St. Pauli      0.5955     0.2419     0.1626  0.841324  1.672850
# 344          Augsburg      0.0601     0.1450     0.7949 -1.184070  1.074150
#
# [5 rows x 30 columns]

# %%
# df[(df['team_title'] == team_1) | (df['team_title'] == team_2)].head(20)

df.columns
# Out:
# Index(['league', 'team_id', 'team_title', 'gameweek', 'h_a', 'xG', 'xGA',
#        'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep', 'deep_allowed',
#        'scored', 'conceded', 'xpts', 'result', 'date', 'wins', 'draws',
#        'loses', 'pts', 'npxGD', 'adv_id', 'adv_title', 'forecast_w',
#        'forecast_d', 'forecast_l', 'xG_diff', 'xGA_diff'],
#       dtype='object')

# %%
teams = [(team_1, team_1_df), (team_2, team_2_df)]

# for team, team_df in teams:
#     content = f"### {team}\n"
#     content += f"Has played **{team_df.shape[0]}** matches\n"
#     #content += f"Has played **{team_df.shape[0]}** games with an average of **{team_df['pts'].mean()}** points per game"


#     display(Markdown(content))

cols = [
    "__Points__",
    ("pts", "mean", "Points (mean)", 1),
    ("xpts", "mean", "Expected Points (mean)", 0),
    "__Attacking__",
    ("xG", "mean", "Expected goals (mean)", 1),
    ("ppda_allowed", "mean", "PPDA allowed (mean)", 1),
    ("npxG", "mean", "Non-penalty xG (mean)", 1),
    ("deep", "mean", "Deep passes (mean)", 1),
    "__Scoring__",
    ("scored", "mean", "Goals scored (mean)", 1),
    # ("scored", "sum", "Goals scored (sum)", 1),
    ("xG_diff", "mean", "xG diff (mean)", 1),
    "__Defending__",
    ("ppda", "mean", "PPDA (mean)", -1),
    ("xGA", "mean", "xG allowed (mean)", -1),
    ("conceded", "mean", "Goals conceded (mean)", -1),
    ("npxGA", "mean", "Non-penalty xG allowed (mean)", -1),
    ("deep_allowed", "mean", "Deep passes allowed (mean)", - 1),
    "__Other__",
    ("deep", "sum", "Deep passes (sum)", 1),
    ("deep_allowed", "sum", "Deep passes allowed (sum)", - 1),
    ("npxGD", "mean", "Non-penalty xG diff (mean)", -1),
    ("xGA_diff", "sum", "xG allowed diff (sum)", 1),
]


table = "<table>"
table += f"<tr><td></td><th>{team_1}</th><th>{team_2}</th></tr>"
for col in cols:
    if type(col) == str:
        table += f"<tr><td colspan='3' style='text-align: center;'>{col.replace('__', ' ---------- ')}</td></tr>"
        continue

    c, fn, title, best = col
    if fn == "mean":
        v1 = team_1_df[c].mean()
        v2 = team_2_df[c].mean()
    elif fn == "sum":
        v1 = team_1_df[c].sum()
        v2 = team_2_df[c].sum()

    c1 = ""
    c2 = ""
    if best == 1:
        if v1 > v2:
            c1 = "green"
        elif v1 < v2:
            c2 = "green"
    elif best == -1:
        if v1 < v2:
            c1 = "green"
        elif v1 > v2:
            c2 = "green"

    table += f"<tr><td style='text-align: left;'>{title}</td><td style='color:{c1}'>{v1.round(decimals=2)}</td><td style='color:{c2}'>{v2.round(decimals=2)}</td></tr>"
    
table += "</table>"
display(HTML(table))
# Out:
# <table><tr><td></td><th>Juventus</th><th>RasenBallsport Leipzig</th></tr><tr><td colspan='3' style='text-align: center;'> ---------- Points ---------- </td></tr><tr><td style='text-align: left;'>Points (mean)</td><td style='color:'>2.0</td><td style='color:green'>2.2</td></tr><tr><td style='text-align: left;'>Expected Points (mean)</td><td style='color:'>1.86</td><td style='color:'>1.28</td></tr><tr><td colspan='3' style='text-align: center;'> ---------- Attacking ---------- </td></tr><tr><td style='text-align: left;'>Expected goals (mean)</td><td style='color:'>1.19</td><td style='color:green'>1.48</td></tr><tr><td style='text-align: left;'>PPDA allowed (mean)</td><td style='color:'>17.14</td><td style='color:green'>17.84</td></tr><tr><td style='text-align: left;'>Non-penalty xG (mean)</td><td style='color:'>0.94</td><td style='color:green'>1.33</td></tr><tr><td style='text-align: left;'>Deep passes (mean)</td><td style='color:'>5.17</td><td style='color:green'>6.6</td></tr><tr><td colspan='3' style='text-align: center;'> ---------- Scoring ---------- </td></tr><tr><td style='text-align: left;'>Goals scored (mean)</td><td style='color:'>1.5</td><td style='color:green'>1.6</td></tr><tr><td style='text-align: left;'>xG diff (mean)</td><td style='color:'>-0.31</td><td style='color:green'>-0.12</td></tr><tr><td colspan='3' style='text-align: center;'> ---------- Defending ---------- </td></tr><tr><td style='text-align: left;'>PPDA (mean)</td><td style='color:'>12.7</td><td style='color:green'>10.94</td></tr><tr><td style='text-align: left;'>xG allowed (mean)</td><td style='color:green'>0.44</td><td style='color:'>1.67</td></tr><tr><td style='text-align: left;'>Goals conceded (mean)</td><td style='color:green'>0.0</td><td style='color:'>0.4</td></tr><tr><td style='text-align: left;'>Non-penalty xG allowed (mean)</td><td style='color:green'>0.44</td><td style='color:'>1.52</td></tr><tr><td style='text-align: left;'>Deep passes allowed (mean)</td><td style='color:green'>3.17</td><td style='color:'>7.6</td></tr><tr><td colspan='3' style='text-align: center;'> ---------- Other ---------- </td></tr><tr><td style='text-align: left;'>Deep passes (sum)</td><td style='color:'>31</td><td style='color:green'>33</td></tr><tr><td style='text-align: left;'>Deep passes allowed (sum)</td><td style='color:green'>19</td><td style='color:'>38</td></tr><tr><td style='text-align: left;'>Non-penalty xG diff (mean)</td><td style='color:'>0.5</td><td style='color:green'>-0.19</td></tr><tr><td style='text-align: left;'>xG allowed diff (sum)</td><td style='color:'>2.65</td><td style='color:green'>6.34</td></tr></table>

# %%
t_col = ['team_title', 'league']
cols = [*t_col, 'xG', 'xGA', 'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep', 'deep_allowed', 'scored', 'conceded', 'pts', 'npxGD', 'xGA_diff', 'xG_diff']


m_df = df[cols].groupby(['team_title', 'league']).mean() 
m_df.reset_index(inplace=True)  

# m_df.head()
# Out:
#     team_title   league        xG       xGA      npxG     npxGA       ppda  \
# 0     AC Milan  Serie_A  2.153347  1.222643  1.899581  1.222643  16.213333
# 1       Alaves  La_liga  1.474004  1.323026  1.288185  1.137207  12.351250
# 2       Angers  Ligue_1  0.854943  2.129848  0.601578  2.129848  10.940000
# 3      Arsenal      EPL  2.319722  1.266057  2.319722  1.266057   9.023333
# 4  Aston Villa      EPL  2.138000  1.368631  2.138000  1.241769  11.336667
#
#    ppda_allowed      deep  deep_allowed    scored  conceded       pts  \
# 0     22.738333  7.666667      4.833333  2.333333  1.166667  1.833333
# 1      8.345000  4.000000      4.250000  1.375000  1.500000  1.250000
# 2      9.405000  4.500000      5.666667  0.666667  2.000000  0.333333
# 3     13.566667  9.166667      6.333333  2.000000  0.833333  2.333333
# 4     11.325000  6.666667      5.166667  2.000000  1.500000  2.166667
#
#       npxGD  xGA_diff   xG_diff
# 0  0.676938  0.055976 -0.179987
# 1  0.150977 -0.176974  0.099003
# 2 -1.528270  0.129848  0.188276
# 3  1.053665  0.432723  0.319722
# 4  0.896231 -0.131369  0.138000

# %%
cols = [('xG', False), ('xGA', True), ('ppda', True), ('ppda_allowed', False), ('deep', False), ('deep_allowed', True), ('scored', False), ('conceded', True), ('pts', False), ('npxGD', False), ('xGA_diff', False), ('xG_diff', False)]
leagues = ['Serie_A', 'Bundesliga']
teams = ['Juventus', 'RasenBallsport Leipzig']
table = ""
for c, asc in cols:
    for league in leagues:
        table += f"<div style='margin:10px'><h3>{c} {league}</h3><table>"
        vals = m_df[m_df['league'] == league].sort_values(c, ascending=asc)[['team_title', c]].values

        for i, (team, xG) in enumerate(vals):
            color = ""
            if team in teams:
                color = "green"
            table += f"<tr style='color:{color}'><td>{i+1}</td><td>{team}</td><td>{xG}</td></tr>"
        table += "</table></div>"

display(HTML("<div style='display:flex; flex-direction:row;flex-wrap: wrap;'>"+table+"</div>"))
# Out:
# <div style='display:flex; flex-direction:row;flex-wrap: wrap;'><div style='margin:10px'><h3>xG Serie_A</h3><table><tr style='color:'><td>1</td><td>Atalanta</td><td>2.1614383333333334</td></tr><tr style='color:'><td>2</td><td>AC Milan</td><td>2.1533466666666667</td></tr><tr style='color:'><td>3</td><td>Parma Calcio 1913</td><td>2.0204283333333333</td></tr><tr style='color:'><td>4</td><td>Inter</td><td>1.9716736666666665</td></tr><tr style='color:'><td>5</td><td>Lazio</td><td>1.9215200000000001</td></tr><tr style='color:'><td>6</td><td>Roma</td><td>1.8225501666666666</td></tr><tr style='color:'><td>7</td><td>Cagliari</td><td>1.6765701666666668</td></tr><tr style='color:'><td>8</td><td>Fiorentina</td><td>1.6605655</td></tr><tr style='color:'><td>9</td><td>Como</td><td>1.4051168333333333</td></tr><tr style='color:'><td>10</td><td>Napoli</td><td>1.4002481666666666</td></tr><tr style='color:'><td>11</td><td>Torino</td><td>1.3489575</td></tr><tr style='color:'><td>12</td><td>Bologna</td><td>1.3322993333333333</td></tr><tr style='color:'><td>13</td><td>Lecce</td><td>1.32386</td></tr><tr style='color:'><td>14</td><td>Udinese</td><td>1.3071895</td></tr><tr style='color:'><td>15</td><td>Verona</td><td>1.2743281666666666</td></tr><tr style='color:green'><td>16</td><td>Juventus</td><td>1.1909945</td></tr><tr style='color:'><td>17</td><td>Venezia</td><td>1.1774933333333333</td></tr><tr style='color:'><td>18</td><td>Empoli</td><td>1.1410103333333332</td></tr><tr style='color:'><td>19</td><td>Genoa</td><td>1.1151091666666668</td></tr><tr style='color:'><td>20</td><td>Monza</td><td>0.4071111666666667</td></tr></table></div><div style='margin:10px'><h3>xG Bundesliga</h3><table><tr style='color:'><td>1</td><td>VfB Stuttgart</td><td>2.690305</td></tr><tr style='color:'><td>2</td><td>Bayern Munich</td><td>2.4953700000000003</td></tr><tr style='color:'><td>3</td><td>Eintracht Frankfurt</td><td>2.414482</td></tr><tr style='color:'><td>4</td><td>Bayer Leverkusen</td><td>2.37651726</td></tr><tr style='color:'><td>5</td><td>Borussia Dortmund</td><td>2.0926763999999998</td></tr><tr style='color:'><td>6</td><td>Freiburg</td><td>2.0565044</td></tr><tr style='color:'><td>7</td><td>Borussia M.Gladbach</td><td>1.7633240000000001</td></tr><tr style='color:'><td>8</td><td>Augsburg</td><td>1.6883527999999999</td></tr><tr style='color:'><td>9</td><td>Hoffenheim</td><td>1.5596644</td></tr><tr style='color:'><td>10</td><td>Werder Bremen</td><td>1.5399445999999999</td></tr><tr style='color:green'><td>11</td><td>RasenBallsport Leipzig</td><td>1.4788656</td></tr><tr style='color:'><td>12</td><td>FC Heidenheim</td><td>1.4697692</td></tr><tr style='color:'><td>13</td><td>Mainz 05</td><td>1.4044968</td></tr><tr style='color:'><td>14</td><td>Wolfsburg</td><td>1.3301292</td></tr><tr style='color:'><td>15</td><td>Holstein Kiel</td><td>1.2931072000000001</td></tr><tr style='color:'><td>16</td><td>Bochum</td><td>1.1388678</td></tr><tr style='color:'><td>17</td><td>St. Pauli</td><td>1.0761994</td></tr><tr style='color:'><td>18</td><td>Union Berlin</td><td>0.9173029999999999</td></tr></table></div><div style='margin:10px'><h3>xGA Serie_A</h3><table><tr style='color:green'><td>1</td><td>Juventus</td><td>0.4421201666666667</td></tr><tr style='color:'><td>2</td><td>Napoli</td><td>0.9752228333333334</td></tr><tr style='color:'><td>3</td><td>Lazio</td><td>1.1887183333333333</td></tr><tr style='color:'><td>4</td><td>AC Milan</td><td>1.2226428333333335</td></tr><tr style='color:'><td>5</td><td>Fiorentina</td><td>1.2306736666666667</td></tr><tr style='color:'><td>6</td><td>Empoli</td><td>1.2326703333333333</td></tr><tr style='color:'><td>7</td><td>Como</td><td>1.2579833333333335</td></tr><tr style='color:'><td>8</td><td>Inter</td><td>1.2976685000000001</td></tr><tr style='color:'><td>9</td><td>Monza</td><td>1.3790436666666668</td></tr><tr style='color:'><td>10</td><td>Bologna</td><td>1.4620255</td></tr><tr style='color:'><td>11</td><td>Roma</td><td>1.4914133333333333</td></tr><tr styl ...

# %%
pctls = list(np.arange(0.1, 1, 0.1))

pctls_by_col = m_df.quantile(q=pctls)
pctls_by_col_x = [[] for _ in range(len(pctls_by_col.values[0]))]
for v in pctls_by_col.values:
    for i, vv in enumerate(v):
        pctls_by_col_x[i].append(vv)

len(pctls_by_col_x)
# Out:
# 14

# %%
table_content = []

for ic, c in enumerate(cols[2:]):
    row = []
    for team, team_df in teams:
        for i, pct in enumerate(pctls_by_col_x[ic]):
            if team_df[c].mean() > pct and team_df[c].mean() < pctls_by_col[c].max():
                continue
            row.append([team, c, i])
            break
    table_content.append(row)


table = "<table>"
table += f"<tr><td></td><th>{team_1}</th><th>{team_2}</th></tr>"
for ab in table_content:
    _, c, i = ab[0]
    _, _, j = ab[1]
    table += f"<tr><td style='text-align: left;'>{c}</td><td>{(i+1)*10}th</td><td>{(j+1)*10}th</td></tr>"
table += "</table>"
display(HTML(table))
# Out:
# <table><tr><td></td><th>Juventus</th><th>RasenBallsport Leipzig</th></tr><tr><td style='text-align: left;'>xG</td><td>30th</td><td>60th</td></tr><tr><td style='text-align: left;'>xGA</td><td>10th</td><td>60th</td></tr><tr><td style='text-align: left;'>npxG</td><td>20th</td><td>50th</td></tr><tr><td style='text-align: left;'>npxGA</td><td>10th</td><td>60th</td></tr><tr><td style='text-align: left;'>ppda</td><td>60th</td><td>40th</td></tr><tr><td style='text-align: left;'>ppda_allowed</td><td>90th</td><td>90th</td></tr><tr><td style='text-align: left;'>deep</td><td>40th</td><td>60th</td></tr><tr><td style='text-align: left;'>deep_allowed</td><td>10th</td><td>80th</td></tr><tr><td style='text-align: left;'>scored</td><td>60th</td><td>60th</td></tr><tr><td style='text-align: left;'>conceded</td><td>10th</td><td>10th</td></tr><tr><td style='text-align: left;'>pts</td><td>90th</td><td>10th</td></tr><tr><td style='text-align: left;'>npxGD</td><td>80th</td><td>50th</td></tr><tr><td style='text-align: left;'>xGA_diff</td><td>90th</td><td>10th</td></tr><tr><td style='text-align: left;'>xG_diff</td><td>20th</td><td>30th</td></tr></table>

# %%
team_1_df['xG'].mean()
# Out:
# 1.1909945

# %%
len(cols[2:])
# Out:
# 14

# %%
table_content = []

for ic, c in enumerate(cols[2:]):
    row = []
    for team, team_df in teams:
        for i, pct in enumerate(pctls_by_col_x[ic]):
            if team_df[c].mean() > pct and team_df[c].mean() < pctls_by_col[c].max():
                continue
            row.append([team, c, i])
            break
    table_content.append(row)


table = "<table>"
table += f"<tr><td></td><th>{team_1}</th><th>{team_2}</th></tr>"
for ab in table_content:
    _, c, i = ab[0]
    _, _, j = ab[1]
    table += f"<tr><td style='text-align: left;'>{c}</td><td>{(i+1)*10}th</td><td>{(j+1)*10}th</td></tr>"
table += "</table>"
display(HTML(table))
# Out:
# <table><tr><td></td><th>Juventus</th><th>RasenBallsport Leipzig</th></tr><tr><td style='text-align: left;'>xG</td><td>30th</td><td>60th</td></tr><tr><td style='text-align: left;'>xGA</td><td>10th</td><td>60th</td></tr><tr><td style='text-align: left;'>npxG</td><td>20th</td><td>50th</td></tr><tr><td style='text-align: left;'>npxGA</td><td>10th</td><td>60th</td></tr><tr><td style='text-align: left;'>ppda</td><td>60th</td><td>40th</td></tr><tr><td style='text-align: left;'>ppda_allowed</td><td>90th</td><td>90th</td></tr><tr><td style='text-align: left;'>deep</td><td>40th</td><td>60th</td></tr><tr><td style='text-align: left;'>deep_allowed</td><td>10th</td><td>80th</td></tr><tr><td style='text-align: left;'>scored</td><td>60th</td><td>60th</td></tr><tr><td style='text-align: left;'>conceded</td><td>10th</td><td>10th</td></tr><tr><td style='text-align: left;'>pts</td><td>90th</td><td>10th</td></tr><tr><td style='text-align: left;'>npxGD</td><td>80th</td><td>50th</td></tr><tr><td style='text-align: left;'>xGA_diff</td><td>90th</td><td>10th</td></tr><tr><td style='text-align: left;'>xG_diff</td><td>20th</td><td>30th</td></tr></table>
